# %% [markdown]
# #sdk_translator_text
# https://github.com/Azure/azure-sdk-for-python/tree/main/sdk/translation/azure-ai-translation-text/samples
# ##sdk_all
# https://github.com/Azure/azure-sdk-for-python/tree/main/sdk
#
#
#
#
# ###translator_overview
# https://portal.azure.com/#@sdaf7138902gmail.onmicrosoft.com/resource/subscriptions/9cee02bd-f908-4a56-99e5-5ad6a2eaa795/resourceGroups/AI_Workload/providers/Microsoft.CognitiveServices/accounts/translator-test-1234/overview

# %%
# %pip install azure-ai-translation-text==1.0.0b1
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from azure.ai.translation.text import TextTranslationClient
from azure.core.credentials import AzureKeyCredential
from azure.core.exceptions import HttpResponseError
import requests, uuid, json

# %%
apikey = "8P0PECgt3avPVGPECgwdk62Uv0vfn4fxUvT6JdY9HTkAEE4bxPJaJQQJ99BAACxCCsyXJ3w3AAAbACOGNfNF"
region = "japanwest"
endpoint = "https://japanwest.api.cognitive.microsofttranslator.com/"

# %%
credential = AzureKeyCredential(apikey)
text_translator = TextTranslationClient(credential=credential, region=region)

# %%
try:
    to_language = ["cs", "es", "jp"]
    input_text_elements = ["This is a test"]

    response = text_translator.translate(content=input_text_elements, to=to_language)
    translation = response[0] if response else None

    if translation:
        detected_language = translation.detected_language
        if detected_language:
            print(
                f"Detected languages of the input text: {detected_language.language} with score: {detected_language.score}."
            )
        for translated_text in translation.translations:
            print(f"Text was translated to: '{translated_text.to}' and the result is: '{translated_text.text}'.")

except HttpResponseError as exception:
    if exception.error is not None:
        print(f"Error Code: {exception.error.code}")
        print(f"Message: {exception.error.message}")
# Out:
# Error Code: 401001
# Message: The request is not authorized because credentials are missing or invalid.
